# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Deep_Learning_TensorFlow/blob/main/11LazyInitialization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
net = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(10),
])

# %%
[net.layers[i].get_weights() for i in range(len(net.layers))]
# Out:
# [[], []]

# %%
X = tf.random.uniform((2, 20))
net(X)
[w.shape for w in net.get_weights()]
# Out:
# [(20, 256), (256,), (256, 10), (10,)]
