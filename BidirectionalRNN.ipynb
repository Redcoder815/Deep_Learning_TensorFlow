# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Deep_Learning_TensorFlow/blob/main/BidirectionalRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences

features = 2000  # Number of most frequent words to consider
max_len = 50     # Maximum length of each sequence

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=features)

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, SimpleRNN, Dense

embedding_dim = 128
hidden_units = 64

model = Sequential()

model.add(Embedding(features, embedding_dim, input_length=max_len))

model.add(Bidirectional(SimpleRNN(hidden_units)))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
batch_size = 32
epochs = 5

model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 41ms/step - accuracy: 0.5899 - loss: 0.6533 - val_accuracy: 0.7778 - val_loss: 0.4649
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8006 - loss: 0.4371 - val_accuracy: 0.7804 - val_loss: 0.4558
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8317 - loss: 0.3869 - val_accuracy: 0.7691 - val_loss: 0.4734
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8617 - loss: 0.3188 - val_accuracy: 0.7792 - val_loss: 0.5247
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.9053 - loss: 0.2373 - val_accuracy: 0.7644 - val_loss: 0.5816

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Test accuracy:', accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7617 - loss: 0.5897
# Test accuracy: 0.7643600106239319

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5)

print(classification_report(y_test, y_pred, target_names=['Negative', 'Positive']))
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.75      0.76     12500
#     Positive       0.76      0.78      0.77     12500
#
#     accuracy                           0.76     25000
#    macro avg       0.76      0.76      0.76     25000
# weighted avg       0.76      0.76      0.76     25000
